# %% [markdown]
# # VieNeuTTS Colab HF-style runner
# Chạy toàn bộ trên Colab T4: VieNeu render + ffmpeg concat/subtitle + cache/output Drive/HF Dataset. Không cần local.

# %%
# 1) Mount Google Drive để lưu output/cache
from google.colab import drive
drive.mount('/content/drive')
import os
os.environ['GOOGLE_DRIVE_OUTPUT_ROOT'] = '/content/drive/MyDrive/VieNeuTTS_Output'

# %%
# 2) Upload zip package này lên Colab, rồi sửa tên zip nếu cần
PACKAGE_ZIP = '/content/vieneutts_colab_hf_style_package.zip'
APP_DIR = '/content/vieneutts_app'
# !rm -rf {APP_DIR}
# !mkdir -p {APP_DIR}
# !unzip -o {PACKAGE_ZIP} -d {APP_DIR}
# %cd {APP_DIR}

# %%
# 3) Cài system deps + pip deps
# !apt-get update -y
# !apt-get install -y ffmpeg espeak-ng
# !pip install -U -r requirements.txt

# %%
# 4) Optional: dùng Hugging Face Dataset thay Drive
# import os
# os.environ['HF_TOKEN'] = 'hf_xxx'
# os.environ['DATASET_REPO'] = 'username/dataset_name'

# %%
# 5) Chạy Gradio app public link giống Hugging Face Space
# !python app.py
